# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("players-2021.csv")

# %%
df
# Out:
#         last_name  first_name  player_id  year  player_age  p_game  \
# 0      Wainwright        Adam     425794  2021          40      32
# 1         Greinke        Zack     425844  2021          38      30
# 2          Morton     Charlie     450203  2021          38      33
# 3        Scherzer         Max     453286  2021          37      30
# 4           Miley        Wade     489119  2021          35      28
# 5          Gibson        Kyle     502043  2021          34      31
# 6         Darvish          Yu     506433  2021          35      30
# 7        Anderson       Tyler     542881  2021          32      31
# 8            Cole      Gerrit     543037  2021          31      30
# 9      DeSclafani     Anthony     543101  2021          31      31
# 10        Eovaldi      Nathan     543135  2021          31      32
# 11      Hendricks        Kyle     543294  2021          32      32
# 12          Lyles      Jordan     543475  2021          31      32
# ...

# %%
df['p_era'].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['name'] = df[' first_name'] +" " +df['last_name']

# %%
df
# Out:
#         last_name  first_name  player_id  year  player_age  p_game  \
# 0      Wainwright        Adam     425794  2021          40      32
# 1         Greinke        Zack     425844  2021          38      30
# 2          Morton     Charlie     450203  2021          38      33
# 3        Scherzer         Max     453286  2021          37      30
# 4           Miley        Wade     489119  2021          35      28
# 5          Gibson        Kyle     502043  2021          34      31
# 6         Darvish          Yu     506433  2021          35      30
# 7        Anderson       Tyler     542881  2021          32      31
# 8            Cole      Gerrit     543037  2021          31      30
# 9      DeSclafani     Anthony     543101  2021          31      31
# 10        Eovaldi      Nathan     543135  2021          31      32
# 11      Hendricks        Kyle     543294  2021          32      32
# 12          Lyles      Jordan     543475  2021          31      32
# ...

# %%
df.to_json('player_data.json', orient='records', indent=2, force_ascii = False)
