# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import warnings
warnings.simplefilter('ignore')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
from tensorflow.keras.models import load_model
outs_model = load_model("outs_predictor_model_trained.h5")

# %%
df = pd.read_csv("prospect_data_for_model.csv")
df.head()
# Out:
#    last_name  first_name  player_id  year  player_age  p_game  p_formatted_ip  \
# 0  Uberstine       Tyler          1  2021          22       6            39.2
# 1    Lavelle       Quinn          2  2021          22       6            38.0
# 2    Doherty        Mike          3  2021          23       5            63.1
#
#    p_total_pa  p_total_hits  p_k_percent  ...  straightaway_percent  \
# 0         312            53         22.1  ...                  40.2
# 1         312            36         22.1  ...                  40.2
# 2         312            64         22.1  ...                  40.2
#
#    opposite_percent  f_strike_percent  groundballs_percent  flyballs_percent  \
# 0              25.4              63.1                 45.1              20.5
# 1              25.4              63.1                 45.1              20.5
# 2              25.4              63.1                 45.1              20.5
#
#    linedrives_percent  popups_percent  n_fastball_formatted  \
# 0                29.5             4.9                  60.2
# 1                29.5             4.9                  60.2
# 2                29.5             4.9                  60.2
#
#    n_breaking_formatted  n_offspeed_formatted
# 0                  30.7                   9.2
# 1                  30.7                   9.2
# 2                  30.7                   9.2
#
# [3 rows x 36 columns]

# %%
selected_features = df[['player_age',  'p_k_percent',\
                       'p_bb_percent', 'z_swing_percent', 'z_swing_miss_percent', 'oz_swing_percent', 'oz_swing_miss_percent',\
                        'oz_contact_percent', 'out_zone_percent', 'meatball_percent', 'iz_contact_percent', 'in_zone_percent',\
                        'edge_percent', 'whiff_percent', 'swing_percent', 'f_strike_percent', 'groundballs_percent', 'flyballs_percent', 'linedrives_percent',\
                        'popups_percent', 'n_fastball_formatted', 'n_breaking_formatted', 'n_offspeed_formatted' ]]

# %%
X = selected_features
y = df[['p_out']]
print(X.shape, y.shape)
# Out:
# (3, 23) (3, 1)

# %%
X_scaler = StandardScaler().fit(X)
X_scaled = X_scaler.transform(X)

# %%
prediction = outs_model.predict(X_scaled)
prediction
# Out:
# array([[283.2662 ],
#        [283.2662 ],
#        [262.33316]], dtype=float32)

# %%
df["predicted_outs"] = prediction
df.head()
# Out:
#    last_name  first_name  player_id  year  player_age  p_game  p_formatted_ip  \
# 0  Uberstine       Tyler          1  2021          22       6            39.2
# 1    Lavelle       Quinn          2  2021          22       6            38.0
# 2    Doherty        Mike          3  2021          23       5            63.1
#
#    p_total_pa  p_total_hits  p_k_percent  ...  opposite_percent  \
# 0         312            53         22.1  ...              25.4
# 1         312            36         22.1  ...              25.4
# 2         312            64         22.1  ...              25.4
#
#    f_strike_percent  groundballs_percent  flyballs_percent  \
# 0              63.1                 45.1              20.5
# 1              63.1                 45.1              20.5
# 2              63.1                 45.1              20.5
#
#    linedrives_percent  popups_percent  n_fastball_formatted  \
# 0                29.5             4.9                  60.2
# 1                29.5             4.9                  60.2
# 2                29.5             4.9                  60.2
#
#    n_breaking_formatted  n_offspeed_formatted  predicted_outs
# 0                  30.7                   9.2      283.266205
# 1                  30.7                   9.2      283.266205
# 2                  30.7                   9.2      262.333160
#
# [3 rows x 37 columns]

# %%
df.to_csv("prospect_outs_predictions_22.csv")
