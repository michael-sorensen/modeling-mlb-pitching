# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv("project_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#     last_name  first_name  player_id  year  player_age  p_game  \
# 0  Wainwright        Adam     425794  2020          39      10
# 1     Greinke        Zack     425844  2020          37      12
# 2      Lester         Jon     452657  2020          36      12
# 3    Scherzer         Max     453286  2020          36      12
# 4       Cueto      Johnny     456501  2020          34      12
#
#    p_formatted_ip  p_total_pa  p_total_hits  p_k_percent  ...  \
# 0            65.2         262            54         20.6  ...
# 1            67.0         273            67         24.5  ...
# 2            61.0         265            64         15.8  ...
# 3            67.1         295            70         31.2  ...
# 4            63.1         277            61         20.2  ...
#
#    straightaway_percent  opposite_percent  f_strike_percent  \
# 0                  39.8              20.9              67.6
# 1                  42.3              26.0              61.9
# 2                  41.4              23.2              58.9
# 3                  32.4              33.0              65.8
# 4                  31.3              20.3              55.6
#
#    groundballs_percent  flyballs_percent  linedrives_percent  popups_percent  \
# 0                 44.0              21.5                27.7             6.8
# 1                 42.9              18.9                30.6             7.7
# 2                 48.3              23.2                23.6             4.9
# 3                 34.6              22.3                34.1             8.9
# 4                 42.7              22.4                30.2             4.7
#
#    n_fastball_formatted  n_breaking_formatted  n_offspeed_formatted
# 0                  59.2                  38.3                   2.5
# 1                  43.5                  33.2                  23.3
# 2                  73.7                  12.8                  13.5
# 3                  55.6                  28.4                  16.1
# 4                  43.7                  29.2                  27.1
#
# [5 rows x 36 columns]

# %%
df.dtypes
# Out:
# last_name                 object
#  first_name               object
# player_id                  int64
# year                       int64
# player_age                 int64
# p_game                     int64
# p_formatted_ip           float64
# p_total_pa                 int64
# p_total_hits               int64
# p_k_percent              float64
# p_bb_percent             float64
# p_out                      int64
# p_era                    float64
# z_swing_percent          float64
# z_swing_miss_percent     float64
# oz_swing_percent         float64
# oz_swing_miss_percent    float64
# oz_contact_percent       float64
# out_zone_percent         float64
# meatball_percent         float64
# iz_contact_percent       float64
# in_zone_percent          float64
# edge_percent             float64
# whiff_percent            float64
# swing_percent            float64
# pull_percent             float64
# straightaway_percent     float64
# opposite_percent         float64
# f_strike_percent         float64
# groundballs_percent      float64
# flyballs_percent         float64
# linedrives_percent       float64
# popups_percent           float64
# n_fastball_formatted     float64
# n_breaking_formatted     float64
# n_offspeed_formatted     float64
# dtype: object

# %%
# Set features. This will also be used as your x values.
selected_features = df[['player_age', 'p_game', 'p_formatted_ip', 'p_total_pa', 'p_total_hits', 'p_k_percent',\
                       'p_bb_percent', 'z_swing_percent', 'z_swing_miss_percent', 'oz_swing_percent', 'oz_swing_miss_percent',\
                        'oz_contact_percent', 'out_zone_percent', 'meatball_percent', 'iz_contact_percent', 'in_zone_percent',\
                        'edge_percent', 'whiff_percent', 'swing_percent', 'pull_percent', 'straightaway_percent',\
                        'opposite_percent', 'f_strike_percent', 'groundballs_percent', 'flyballs_percent', 'linedrives_percent',\
                        'popups_percent', 'n_fastball_formatted', 'n_breaking_formatted', 'n_offspeed_formatted' ]]

# %%
selected_features.head()
# Out:
#    player_age  p_game  p_formatted_ip  p_total_pa  p_total_hits  p_k_percent  \
# 0          39      10            65.2         262            54         20.6
# 1          37      12            67.0         273            67         24.5
# 2          36      12            61.0         265            64         15.8
# 3          36      12            67.1         295            70         31.2
# 4          34      12            63.1         277            61         20.2
#
#    p_bb_percent  z_swing_percent  z_swing_miss_percent  oz_swing_percent  ...  \
# 0           5.7             62.9                  15.2              30.2  ...
# 1           3.3             59.7                  17.0              26.3  ...
# 2           6.4             67.4                  11.3              25.9  ...
# 3           7.8             71.5                  25.8              30.1  ...
# 4           9.4             68.1                  14.5              25.8  ...
#
#    straightaway_percent  opposite_percent  f_strike_percent  \
# 0                  39.8              20.9              67.6
# 1                  42.3              26.0              61.9
# 2                  41.4              23.2              58.9
# 3                  32.4              33.0              65.8
# 4                  31.3              20.3              55.6
#
#    groundballs_percent  flyballs_percent  linedrives_percent  popups_percent  \
# 0                 44.0              21.5                27.7             6.8
# 1                 42.9              18.9                30.6             7.7
# 2                 48.3              23.2                23.6             4.9
# 3                 34.6              22.3                34.1             8.9
# 4                 42.7              22.4                30.2             4.7
#
#    n_fastball_formatted  n_breaking_formatted  n_offspeed_formatted
# 0                  59.2                  38.3                   2.5
# 1                  43.5                  33.2                  23.3
# 2                  73.7                  12.8                  13.5
# 3                  55.6                  28.4                  16.1
# 4                  43.7                  29.2                  27.1
#
# [5 rows x 30 columns]

# %%
X = selected_features
y = df[['p_era']]
print(X.shape, y.shape)
# Out:
# (323, 30) (323, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential()
model.add(Dense(units=35, activation = "relu", input_dim = 30))
model.add(Dense(units=35, activation = "relu"))
model.add(Dense(units=1, activation = "relu"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 35)                1085
# _________________________________________________________________
# dense_1 (Dense)              (None, 35)                1260
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 36
# =================================================================
# Total params: 2,381
# Trainable params: 2,381
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mean_absolute_error'])

# %%
# Fit the model to the training data
#look up validation error, train fit vs validation fit, make sure it's not overfitting
# validation error > train error, that's when you have your epoch number
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.2,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 7/7 - 1s - loss: 13.9478 - mean_absolute_error: 3.6321 - val_loss: 14.9711 - val_mean_absolute_error: 3.7898
# Epoch 2/100
# 7/7 - 0s - loss: 12.7476 - mean_absolute_error: 3.4628 - val_loss: 13.3912 - val_mean_absolute_error: 3.5741
# Epoch 3/100
# 7/7 - 0s - loss: 11.0714 - mean_absolute_error: 3.2060 - val_loss: 11.3841 - val_mean_absolute_error: 3.2765
# Epoch 4/100
# 7/7 - 0s - loss: 8.9262 - mean_absolute_error: 2.8400 - val_loss: 8.9758 - val_mean_absolute_error: 2.8832
# Epoch 5/100
# 7/7 - 0s - loss: 6.7709 - mean_absolute_error: 2.4200 - val_loss: 6.7869 - val_mean_absolute_error: 2.4659
# Epoch 6/100
# 7/7 - 0s - loss: 4.9896 - mean_absolute_error: 2.0075 - val_loss: 4.9294 - val_mean_absolute_error: 2.0381
# Epoch 7/100
# 7/7 - 0s - loss: 3.6043 - mean_absolute_error: 1.6414 - val_loss: 3.4807 - val_mean_absolute_error: 1.6355
# Epoch 8/100
# 7/7 - 0s - loss: 2.6734 - mean_absolute_error: 1.3689 - val_loss: 2.4836 - val_mean_absolute_error: 1.3407
# Epoch 9/100
# 7/7 - 0s - loss: 2.1107 - mean_absolute_error: 1.1940 - val_loss: 1.9184 - val_mean_absolute_error: 1.1437
# Epoch 10/100
# 7/7 - 0s - loss: 1.8436 - mean_absolute_error: 1.0944 - val_loss: 1.6468 - val_mean_absolute_error: 1.0246
# Epoch 11/100
# 7/7 - 0s - loss: 1.6939 - mean_absolute_error: 1.0491 - val_loss: 1.5454 - val_mean_absolute_error: 0.9783
# Epoch 12/100
# 7/7 - 0s - loss: 1.5622 - mean_absolute_error: 1.0130 - val_loss: 1.6047 - val_mean_absolute_error: 0.9950
# Epoch 13/100
# 7/7 - 0s - loss: 1.4713 - mean_absolute_error: 0.9917 - val_loss: 1.6416 - val_mean_absolute_error: 1.0013
# Epoch 14/100
# 7/7 - 0s - loss: 1.3948 - mean_absolute_error: 0.9651 - val_loss: 1.6212 - val_mean_absolute_error: 0.9927
# Epoch 15/100
# 7/7 - 0s - loss: 1.3273 - mean_absolute_error: 0.9397 - val_loss: 1.5940 - val_mean_absolute_error: 0.9846
# Epoch 16/100
# 7/7 - 0s - loss: 1.2732 - mean_absolute_error: 0.9148 - val_loss: 1.5693 - val_mean_absolute_error: 0.9807
# Epoch 17/100
# 7/7 - 0s - loss: 1.2257 - mean_absolute_error: 0.8946 - val_loss: 1.5324 - val_mean_absolute_error: 0.9673
# Epoch 18/100
# 7/7 - 0s - loss: 1.1842 - mean_absolute_error: 0.8799 - val_loss: 1.4520 - val_mean_absolute_error: 0.9327
# Epoch 19/100
# 7/7 - 0s - loss: 1.1844 - mean_absolute_error: 0.8849 - val_loss: 1.4072 - val_mean_absolute_error: 0.9186
# Epoch 20/100
# 7/7 - 0s - loss: 1.1496 - mean_absolute_error: 0.8730 - val_loss: 1.4087 - val_mean_absolute_error: 0.9202
# Epoch 21/100
# 7/7 - 0s - loss: 1.1100 - mean_absolute_error: 0.8554 - val_loss: 1.4416 - val_mean_absolute_error: 0.9467
# Epoch 22/100
# 7/7 - 0s - loss: 1.0734 - mean_absolute_error: 0.8424 - val_loss: 1.4807 - val_mean_absolute_error: 0.9697
# Epoch 23/100
# 7/7 - 0s - loss: 1.0446 - mean_absolute_error: 0.8290 - val_loss: 1.4521 - val_mean_absolute_error: 0.9562
# Epoch 24/100
# 7/7 - 0s - loss: 1.0137 - mean_absolute_error: 0.8134 - val_loss: 1.4251 - val_mean_absolute_error: 0.9437
# Epoch 25/100
# 7/7 - 0s - loss: 0.9871 - mean_absolute_error: 0.8020 - val_loss: 1.4182 - val_mean_absolute_error: 0.9412
# Epoch 26/100
# 7/7 - 0s - loss: 0.9658 - mean_absolute_error: 0.7928 - val_loss: 1.3965 - val_mean_absolute_error: 0.9280
# Epoch 27/100
# 7/7 - 0s - loss: 0.9372 - mean_absolute_error: 0.7791 - val_loss: 1.3847 - val_mean_absolute_error: 0.9202
# Epoch 28/100
# 7/7 - 0s - loss: 0.9149 - mean_absolute_error: 0.7674 - val_loss: 1.3810 - val_mean_absolute_error: 0.9198
# Epoch 29/100
# 7/7 - 0s - loss: 0.8908 - mean_absolute_error: 0.7572 - val_loss: 1.3868 - val_mean_absolute_error: 0.9251
# Epoch 30/100
# 7/7 - 0s - loss: 0.8703 - mean_absolute_error: 0.7471 - val_loss: 1.3970 - val_mean_absolute_error: 0.9363
# Epoch 31/100
# 7/7 - 0s - loss: 0.8500 - mean_absolute_error: 0.7391 - val_loss: 1.3748 - val_mean_absolute_error: 0.9316
# Epoch 32/100
# 7/7 - 0s - loss: 0.8328 - mean_absolute_error: 0.7304 - val_loss: 1.3394 - val_mean_absolute_error: 0.9180
# Epoch 33/100
# 7/7 - 0s - loss: 0.8121 - mean_absolute_error: 0.7203 - val_loss: 1.3183 - val_mean_absolute_error: 0.9120
# Epoch 34/100
# 7/7 - 0s - loss: 0.7987 - mean_absolute_error: 0.7147 - val_loss: 1.2706 - val_mean_absolute_error: 0.8914
# Epoch 35/100
# 7/7 - 0s - loss: 0.7852 - mean_absolute_error: 0.7063 - val_loss: 1.2488 - val_mean_absolute_error: 0.8856
# Epoch 36/100
# 7/7 - 0s - loss: 0.7686 - mean_absolute_error: 0.6984 - val_loss: 1.2415 - val_mean_absolute_error: 0.8833
# Epoch 37/100
# 7/7 - 0s - loss: 0.7527 - mean_absolute_error: 0.6910 - val_loss: 1.2369 - val_mean_absolute_error: 0.8807
# Epoch 38/100
# 7/7 - 0s - loss: 0.7348 - mean_absolute_error: 0.6811 - val_loss: 1.3207 - val_mean_absolute_error: 0.9203
# Epoch 39/100
# 7/7 - 0s - loss: 0.7410 - mean_absolute_error: 0.6823 - val_loss: 1.3370 - val_mean_absolute_error: 0.9310
# Epoch 40/100
# 7/7 - 0s - loss: 0.7359 - mean_absolute_error: 0.6795 - val_loss: 1.3234 - val_mean_absolute_error: 0.9283
# Epoch 41/100
# 7/7 - 0s - loss: 0.7200 - mean_absolute_error: 0.6717 - val_loss: 1.2905 - val_mean_absolute_error: 0.9174
# Epoch 42/100
# 7/7 - 0s - loss: 0.7009 - mean_absolute_error: 0.6678 - val_loss: 1.3512 - val_mean_absolute_error: 0.9536
# Epoch 43/100
# 7/7 - 0s - loss: 0.6974 - mean_absolute_error: 0.6707 - val_loss: 1.3537 - val_mean_absolute_error: 0.9565
# Epoch 44/100
# 7/7 - 0s - loss: 0.6851 - mean_absolute_error: 0.6683 - val_loss: 1.3346 - val_mean_absolute_error: 0.9403
# Epoch 45/100
# 7/7 - 0s - loss: 0.6743 - mean_absolute_error: 0.6697 - val_loss: 1.2923 - val_mean_absolute_error: 0.9139
# Epoch 46/100
# 7/7 - 0s - loss: 0.6603 - mean_absolute_error: 0.6632 - val_loss: 1.2642 - val_mean_absolute_error: 0.9044
# Epoch 47/100
# 7/7 - 0s - loss: 0.6362 - mean_absolute_error: 0.6496 - val_loss: 1.2441 - val_mean_absolute_error: 0.9035
# Epoch 48/100
# 7/7 - 0s - loss: 0.6107 - mean_absolute_error: 0.6314 - val_loss: 1.2331 - val_mean_absolute_error: 0.9113
# Epoch 49/100
# 7/7 - 0s - loss: 0.5958 - mean_absolute_error: 0.6162 - val_loss: 1.2138 - val_mean_absolute_error: 0.8988
# Epoch 50/100
# 7/7 - 0s - loss: 0.5843 - mean_absolute_error: 0.6089 - val_loss: 1.1922 - val_mean_absolute_error: 0.8866
# Epoch 51/100
# 7/7 - 0s - loss: 0.5736 - mean_absolute_error: 0.6021 - val_loss: 1.1729 - val_mean_absolute_error: 0.8757
# Epoch 52/100
# 7/7 - 0s - loss: 0.5624 - mean_absolute_error: 0.5967 - val_loss: 1.1559 - val_mean_absolute_error: 0.8669
# Epoch 53/100
# 7/7 - 0s - loss: 0.5527 - mean_absolute_error: 0.5923 - val_loss: 1.1384 - val_mean_absolute_error: 0.8610
# Epoch 54/100
# 7/7 - 0s - loss: 0.5435 - mean_absolute_error: 0.5881 - val_loss: 1.1299 - val_mean_absolute_error: 0.8596
# Epoch 55/100
# 7/7 - 0s - loss: 0.5368 - mean_absolute_error: 0.5850 - val_loss: 1.1248 - val_mean_absolute_error: 0.8570
# Epoch 56/100
# 7/7 - 0s - loss: 0.5298 - mean_absolute_error: 0.5798 - val_loss: 1.1225 - val_mean_absolute_error: 0.8575
# Epoch 57/100
# 7/7 - 0s - loss: 0.5202 - mean_absolute_error: 0.5726 - val_loss: 1.1402 - val_mean_absolute_error: 0.8748
# Epoch 58/100
# 7/7 - 0s - loss: 0.5134 - mean_absolute_error: 0.5673 - val_loss: 1.1574 - val_mean_absolute_error: 0.8904
# Epoch 59/100
# 7/7 - 0s - loss: 0.5135 - mean_absolute_error: 0.5663 - val_loss: 1.1580 - val_mean_absolute_error: 0.8932
# Epoch 60/100
# 7/7 - 0s - loss: 0.4999 - mean_absolute_error: 0.5596 - val_loss: 1.1341 - val_mean_absolute_error: 0.8823
# Epoch 61/100
# 7/7 - 0s - loss: 0.4907 - mean_absolute_error: 0.5555 - val_loss: 1.1421 - val_mean_absolute_error: 0.8923
# Epoch 62/100
# 7/7 - 0s - loss: 0.4876 - mean_absolute_error: 0.5517 - val_loss: 1.1334 - val_mean_absolute_error: 0.8886
# Epoch 63/100
# 7/7 - 0s - loss: 0.4816 - mean_absolute_error: 0.5499 - val_loss: 1.0870 - val_mean_absolute_error: 0.8590
# Epoch 64/100
# 7/7 - 0s - loss: 0.4775 - mean_absolute_error: 0.5499 - val_loss: 1.0460 - val_mean_absolute_error: 0.8325
# Epoch 65/100
# 7/7 - 0s - loss: 0.4650 - mean_absolute_error: 0.5423 - val_loss: 1.0317 - val_mean_absolute_error: 0.8257
# Epoch 66/100
# 7/7 - 0s - loss: 0.4528 - mean_absolute_error: 0.5341 - val_loss: 1.0232 - val_mean_absolute_error: 0.8217
# Epoch 67/100
# 7/7 - 0s - loss: 0.4454 - mean_absolute_error: 0.5298 - val_loss: 0.9952 - val_mean_absolute_error: 0.8043
# Epoch 68/100
# 7/7 - 0s - loss: 0.4436 - mean_absolute_error: 0.5300 - val_loss: 0.9795 - val_mean_absolute_error: 0.7954
# Epoch 69/100
# 7/7 - 0s - loss: 0.4374 - mean_absolute_error: 0.5239 - val_loss: 0.9816 - val_mean_absolute_error: 0.7960
# Epoch 70/100
# 7/7 - 0s - loss: 0.4281 - mean_absolute_error: 0.5174 - val_loss: 0.9900 - val_mean_absolute_error: 0.8039
# Epoch 71/100
# 7/7 - 0s - loss: 0.4175 - mean_absolute_error: 0.5109 - val_loss: 0.9865 - val_mean_absolute_error: 0.8067
# Epoch 72/100
# 7/7 - 0s - loss: 0.4090 - mean_absolute_error: 0.5070 - val_loss: 0.9999 - val_mean_absolute_error: 0.8092
# Epoch 73/100
# 7/7 - 0s - loss: 0.4111 - mean_absolute_error: 0.5109 - val_loss: 1.0014 - val_mean_absolute_error: 0.8120
# Epoch 74/100
# 7/7 - 0s - loss: 0.4005 - mean_absolute_error: 0.5026 - val_loss: 1.0048 - val_mean_absolute_error: 0.8124
# Epoch 75/100
# 7/7 - 0s - loss: 0.3801 - mean_absolute_error: 0.4888 - val_loss: 1.0086 - val_mean_absolute_error: 0.8159
# Epoch 76/100
# 7/7 - 0s - loss: 0.3866 - mean_absolute_error: 0.4954 - val_loss: 1.0288 - val_mean_absolute_error: 0.8294
# Epoch 77/100
# 7/7 - 0s - loss: 0.3867 - mean_absolute_error: 0.4922 - val_loss: 0.9613 - val_mean_absolute_error: 0.7957
# Epoch 78/100
# 7/7 - 0s - loss: 0.3658 - mean_absolute_error: 0.4799 - val_loss: 0.9173 - val_mean_absolute_error: 0.7761
# Epoch 79/100
# 7/7 - 0s - loss: 0.3566 - mean_absolute_error: 0.4763 - val_loss: 0.9101 - val_mean_absolute_error: 0.7780
# Epoch 80/100
# 7/7 - 0s - loss: 0.3497 - mean_absolute_error: 0.4719 - val_loss: 0.9189 - val_mean_absolute_error: 0.7817
# Epoch 81/100
# 7/7 - 0s - loss: 0.3400 - mean_absolute_error: 0.4638 - val_loss: 0.9344 - val_mean_absolute_error: 0.7881
# Epoch 82/100
# 7/7 - 0s - loss: 0.3394 - mean_absolute_error: 0.4615 - val_loss: 0.9631 - val_mean_absolute_error: 0.8072
# Epoch 83/100
# 7/7 - 0s - loss: 0.3416 - mean_absolute_error: 0.4590 - val_loss: 0.9405 - val_mean_absolute_error: 0.7962
# Epoch 84/100
# 7/7 - 0s - loss: 0.3296 - mean_absolute_error: 0.4530 - val_loss: 0.9135 - val_mean_absolute_error: 0.7805
# Epoch 85/100
# 7/7 - 0s - loss: 0.3206 - mean_absolute_error: 0.4465 - val_loss: 0.8947 - val_mean_absolute_error: 0.7688
# Epoch 86/100
# 7/7 - 0s - loss: 0.3133 - mean_absolute_error: 0.4445 - val_loss: 0.8871 - val_mean_absolute_error: 0.7652
# Epoch 87/100
# 7/7 - 0s - loss: 0.3069 - mean_absolute_error: 0.4399 - val_loss: 0.8852 - val_mean_absolute_error: 0.7663
# Epoch 88/100
# 7/7 - 0s - loss: 0.3004 - mean_absolute_error: 0.4327 - val_loss: 0.8904 - val_mean_absolute_error: 0.7724
# Epoch 89/100
# 7/7 - 0s - loss: 0.2970 - mean_absolute_error: 0.4278 - val_loss: 0.8944 - val_mean_absolute_error: 0.7758
# Epoch 90/100
# 7/7 - 0s - loss: 0.2899 - mean_absolute_error: 0.4220 - val_loss: 0.8858 - val_mean_absolute_error: 0.7686
# Epoch 91/100
# 7/7 - 0s - loss: 0.2867 - mean_absolute_error: 0.4272 - val_loss: 0.8589 - val_mean_absolute_error: 0.7537
# Epoch 92/100
# 7/7 - 0s - loss: 0.2909 - mean_absolute_error: 0.4322 - val_loss: 0.8665 - val_mean_absolute_error: 0.7598
# Epoch 93/100
# 7/7 - 0s - loss: 0.2875 - mean_absolute_error: 0.4272 - val_loss: 0.8702 - val_mean_absolute_error: 0.7625
# Epoch 94/100
# 7/7 - 0s - loss: 0.2810 - mean_absolute_error: 0.4235 - val_loss: 0.8326 - val_mean_absolute_error: 0.7373
# Epoch 95/100
# 7/7 - 0s - loss: 0.2800 - mean_absolute_error: 0.4189 - val_loss: 0.8425 - val_mean_absolute_error: 0.7412
# Epoch 96/100
# 7/7 - 0s - loss: 0.2800 - mean_absolute_error: 0.4137 - val_loss: 0.8596 - val_mean_absolute_error: 0.7565
# Epoch 97/100
# 7/7 - 0s - loss: 0.2702 - mean_absolute_error: 0.4065 - val_loss: 0.8673 - val_mean_absolute_error: 0.7697
# Epoch 98/100
# 7/7 - 0s - loss: 0.2542 - mean_absolute_error: 0.3942 - val_loss: 0.8742 - val_mean_absolute_error: 0.7775
# Epoch 99/100
# 7/7 - 0s - loss: 0.2462 - mean_absolute_error: 0.3889 - val_loss: 0.8750 - val_mean_absolute_error: 0.7754
# Epoch 100/100
# 7/7 - 0s - loss: 0.2421 - mean_absolute_error: 0.3868 - val_loss: 0.8740 - val_mean_absolute_error: 0.7703

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
#train evaluation
model_loss, model_accuracy = model.evaluate(
    X_train_scaled, y_train, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.3676 - mean_absolute_error: 0.4641
# Deep Neural Network - Loss: 0.3675808012485504, Accuracy: 0.46409595012664795

# %%
#test evaluation
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 3/3 - 0s - loss: 0.5385 - mean_absolute_error: 0.5190
# Deep Neural Network - Loss: 0.5384645462036133, Accuracy: 0.5189526677131653

# %%
#save model
model.save("era_predictor_model_trained.h5")
