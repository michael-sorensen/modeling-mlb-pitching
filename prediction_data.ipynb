# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("project_data.csv")
df.head()
# Out:
#     last_name  first_name  player_id  year  player_age  p_game  \
# 0  Wainwright        Adam     425794  2020          39      10
# 1     Greinke        Zack     425844  2020          37      12
# 2      Lester         Jon     452657  2020          36      12
# 3    Scherzer         Max     453286  2020          36      12
# 4       Cueto      Johnny     456501  2020          34      12
#
#    p_formatted_ip  p_total_pa  p_total_hits  p_k_percent  ...  \
# 0            65.2         262            54         20.6  ...
# 1            67.0         273            67         24.5  ...
# 2            61.0         265            64         15.8  ...
# 3            67.1         295            70         31.2  ...
# 4            63.1         277            61         20.2  ...
#
#    straightaway_percent  opposite_percent  f_strike_percent  \
# 0                  39.8              20.9              67.6
# 1                  42.3              26.0              61.9
# ...

# %%
df = df.dropna(axis='columns', how='all')
df = df.dropna()

# %%
df.drop(df.index[df["year"] < 2021], inplace=True)
df.head()
# Out:
#      last_name  first_name  player_id  year  player_age  p_game  \
# 40  Wainwright        Adam     425794  2021          40      32
# 41     Greinke        Zack     425844  2021          38      30
# 42      Morton     Charlie     450203  2021          38      33
# 43    Scherzer         Max     453286  2021          37      30
# 44       Miley        Wade     489119  2021          35      28
#
#     p_formatted_ip  p_total_pa  p_total_hits  p_k_percent  ...  \
# 40           206.1         828           168         21.0  ...
# 41           171.0         697           164         17.2  ...
# 42           185.2         756           136         28.6  ...
# 43           179.1         693           119         34.1  ...
# 44           163.0         690           166         18.1  ...
#
#     straightaway_percent  opposite_percent  f_strike_percent  \
# 40                  37.1              22.9              64.3
# 41                  35.6              27.6              66.0
# ...

# %%
df.year.unique()
# Out:
# array([2021], dtype=int64)

# %%
df.to_csv("prediction_data.csv")
